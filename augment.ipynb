# %%
import numpy as np
import dataloader
import augment
from matplotlib import pyplot as plt
import math
# %matplotlib inline

# %%
train_set = dataloader.SimpleReader(path='/home/localadmin/segthor/data/train_resampled2_2_25',patch_size=(128,128,128), multiplier=500, patches_from_single_image=2)
# Out:
# ['Patient_01', 'Patient_02', 'Patient_03', 'Patient_04', 'Patient_05', 'Patient_06', 'Patient_07', 'Patient_08', 'Patient_09', 'Patient_10', 'Patient_11', 'Patient_12', 'Patient_13', 'Patient_14', 'Patient_15', 'Patient_16', 'Patient_17', 'Patient_18', 'Patient_19', 'Patient_20', 'Patient_21', 'Patient_22', 'Patient_23', 'Patient_24', 'Patient_25', 'Patient_26', 'Patient_27', 'Patient_28', 'Patient_29', 'Patient_30', 'Patient_31', 'Patient_32', 'Patient_33', 'Patient_34', 'Patient_35', 'Patient_36', 'Patient_37', 'Patient_38', 'Patient_39', 'Patient_40']

# %%
tmp = train_set[0]
data = tmp[0][0].numpy()
label = tmp[1][0].numpy()


print(data.min(),data.max())
print(label.min(),label.max())
# Out:
# -0.5586343 9.373999
# 0.0 1.0

# %%
plt.imshow(data[0,80,:,:])
plt.show()
plt.imshow(label[0,80,:,:])
plt.show()

# %%
image = batch[0]
transformation = augment.create_identity_transformation(image.shape)

# %%
transformation += augment.create_elastic_transformation(
        image.shape,
        control_point_spacing = 20,
        jitter_sigma = 2)

# %%
transformation += augment.create_rotation_transformation(
        image.shape,
        0.5)

# %%
image = augment.apply_transformation(image, transformation)

# %%
plt.imshow(image[64,:,:])
plt.show()
