# %%
import nibabel as nii
import numpy as np
import os
import tqdm
from skimage import morphology

# %%
predict_paths = ['/home/dlachinov/brats2019/data/predicts/2018',
                '/home/dlachinov/brats2019/data/predicts/020',
                '/home/dlachinov/brats2019/data/predicts/023',
                '/home/dlachinov/brats2019/data/predicts/isensee_2018',
                '/home/dlachinov/brats2019/data/predicts/030',
                '/home/dlachinov/brats2019/data/predicts/031',
                ]
index_path = '/home/dlachinov/brats2019/data/MICCAI_BraTS_2019_Data_Validation'
output_path = '/home/dlachinov/brats2019/data/out_val'

# %%
file_list = [f for f in os.listdir(index_path) if os.path.isdir(os.path.join(index_path,f))]
file_list.sort()
print(len(file_list))
# Out:
# 125

# %%
def reject_small_regions(connectivity, ratio=0.25):
    resulting_connectivity = connectivity.copy()
    unique, counts = np.unique(connectivity, return_counts=True)

    all_nonzero_clusters = np.prod(connectivity.shape) - np.max(counts)

    for i in range(unique.shape[0]):
        if counts[i] < ratio * all_nonzero_clusters:
            resulting_connectivity[resulting_connectivity == unique[i]] = 0

    return resulting_connectivity

# %%
for f in tqdm.tqdm(file_list):
    data_files = []
    affine = None
    for path in predict_paths:
        full_path = os.path.join(path, f+'.nii.gz')
        handle = nii.load(full_path)
        affine = handle.affine
        data_files.append(handle.get_data())

    mean_predict = sum(data_files) / len(data_files)
    
    hard_predict = np.argmax(mean_predict,axis=0).astype(np.uint8)
    
    hard_predict[hard_predict == 3] = 4
    
    nii_output = nii.Nifti1Image(hard_predict.astype(np.uint8), affine)
    nii.save(nii_output, os.path.join(output_path,f+'.nii.gz'))
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]
#
#
#
#   1%|          | 1/125 [00:02<05:11,  2.51s/it]
#
#
#
#   2%|▏         | 2/125 [00:05<05:12,  2.54s/it]
#
#
#
#   2%|▏         | 3/125 [00:07<05:06,  2.51s/it]
#
#
#
#   3%|▎         | 4/125 [00:10<05:05,  2.53s/it]
#
#
#
#   4%|▍         | 5/125 [00:12<05:02,  2.52s/it]
#
#
#
#   5%|▍         | 6/125 [00:15<05:00,  2.53s/it]
#
#
#
#   6%|▌         | 7/125 [00:17<04:55,  2.50s/it]
#
#
#
#   6%|▋         | 8/125 [00:20<04:54,  2.51s/it]
#
#
#
#   7%|▋         | 9/125 [00:22<04:51,  2.51s/it]
#
#
#
#   8%|▊         | 10/125 [00:25<04:49,  2.52s/it]
#
#
#
#   9%|▉         | 11/125 [00:27<04:40,  2.46s/it]
#
#
#
#  10%|▉         | 12/125 [00:30<04:40,  2.48s/it]
#
#
#
#  10%|█         | 13/125 [00:32<04:36,  2.47s/it]
#
#
#
#  11%|█         | 14/125 [00:34<04:33,  2.46s/it]
#
#
#
#  12%|█▏        | 15/125 [00:37<04:30,  2.46s/it]
#
#
#
#  13%|█▎        | 16/125 [00:40<04:33,  2.51s/it]
#
#
#
#  14%|█▎        | 17/125 [00:42<04:28,  2.49s/it]
#
#
#
#  14%|█▍        | 18/125 [00:44<04:25,  2.48s/it]
#
#
#
#  15%|█▌        | 19/125 [00:47<04:16,  2.42s/it]
#
#
#
#  16%|█▌        | 20/125 [00:49<04:14,  2.42s/it]
#
#
#
#  17%|█▋        | 21/125 [00:51<04:10,  2.41s/it]
#
#
#
#  18%|█▊        | 22/125 [00:54<04:09,  2.43s/it]
#
#
#
#  18%|█▊        | 23/125 [00:56<04:06,  2.42s/it]
#
#
#
#  19%|█▉        | 24/125 [00:59<04:06,  2.44s/it]
#
#
#
#  20%|██        | 25/125 [01:01<04:03,  2.44s/it]
#
#
#
#  21%|██        | 26/125 [01:04<03:57,  2.40s/it]
#
#
#
#  22%|██▏       | 27/125 [01:06<03:55,  2.41s/it]
#
#
#
#  22%|██▏       | 28/125 [01:08<03:54,  2.42s/it]
#
#
#
#  23%|██▎       | 29/125 [01:11<03:53,  2.43s/it]
#
#
#
#  24%|██▍       | 30/125 [01:13<03:51,  2.44s/it]
#
#
#
#  25%|██▍       | 31/125 [01:16<03:49,  2.44s/it]
#
#
#
#  26%|██▌       | 32/125 [01:18<03:44,  2.42s/it]
#
#
#
#  26%|██▋       | 33/125 [01:20<03:37,  2.37s/it]
#
#
#
#  27%|██▋       | 34/125 [01:23<03:39,  2.41s/it]
#
#
#
#  28%|██▊       | 35/125 [01:25<03:38,  2.43s/it]
#
#
#
#  29%|██▉       | 36/125 [01:28<03:37,  2.45s/it]
#
#
#
#  30%|██▉       | 37/125 [01:30<03:34,  2.44s/it]
#
#
#
#  30%|███       | 38/125 [01:33<03:31,  2.43s/it]
#
#
#
#  31%|███       | 39/125 [01:35<03:29,  2.44s/it]
#
#
#
#  32%|███▏      | 40/125 [01:38<03:24,  2.41s/it]
#
#
#
#  33%|███▎      | 41/125 [01:40<03:20,  2.39s/it]
#
#
#
#  34%|███▎      | 42/125 [01:42<03:20,  2.42s/it]
#
#
#
#  34%|███▍      | 43/125 [01:44<03:08,  2.30s/it]
#
#
#
#  35%|███▌      | 44/125 [01:47<03:13,  2.38s/it]
#
#
#
#  36%|███▌      | 45/125 [01:49<03:10,  2.38s/it]
#
#
#
#  37%|███▋      | 46/125 [01:52<03:09,  2.39s/it]
#
#
#
#  38%|███▊      | 47/125 [01:54<03:05,  2.38s/it]
#
#
#
#  38%|███▊      | 48/125 [01:57<03:03,  2.38s/it]
#
#
#
#  39%|███▉      | 49/125 [01:59<03:01,  2.39s/it]
#
#
#
#  40%|████      | 50/125 [02:01<03:01,  2.41s/it]
#
#
#
#  41%|████      | 51/125 [02:04<02:57,  2.40s/it]
#
#
#
#  42%|████▏     | 52/125 [02:06<02:58,  2.44s/it]
#
#
#
#  42%|████▏     | 53/125 [02:09<02:54,  2.42s/it]
#
#
#
#  43%|████▎     | 54/125 [02:11<02:51,  2.41s/it]
#
#
#
#  44%|████▍     | 55/125 [02:13<02:46,  2.37s/it]
#
#
#
#  45%|████▍     | 56/125 [02:16<02:42,  2.36s/it]
#
#
#
#  46%|████▌     | 57/125 [02:18<02:40,  2.36s/it]
#
#
#
#  46%|████▋     | 58/125 [02:20<02:39,  2.38s/it]
#
#
#
#  47%|████▋     | 59/125 [02:23<02:38,  2.40s/it]
#
#
#
#  48%|████▊     | 60/125 [02:25<02:35,  2.39s/it]
#
#
#
#  49%|████▉     | 61/125 [02:28<02:34,  2.42s/it]
#
#
#
#  50%|████▉     | 62/125 [02:30<02:31,  2.41s/it]
#
#
#
#  50%|█████     | 63/125 [02:32<02:26,  2.36s/it]
#
#
#
#  51%|█████     | 64/125 [02:35<02:22,  2.33s/it]
#
#
#
#  52%|█████▏    | 65/125 [02:37<02:22,  2.38s/it]
#
#
#
#  53%|█████▎    | 66/125 [02:40<02:21,  2.40s/it]
#
#
#
#  54%|█████▎    | 67/125 [02:42<02:19,  2.41s/it]
#
#
#
#  54%|█████▍    | 68/125 [02:44<02:18,  2.43s/it]
#
#
#
#  55%|█████▌    | 69/125 [02:47<02:17,  2.45s/it]
#
#
#
#  56%|█████▌    | 70/125 [02:49<02:15,  2.46s/it]
#
#
#
#  57%|█████▋    | 71/125 [02:52<02:13,  2.48s/it]
#
#
#
#  58%|█████▊    | 72/125 [02:55<02:11,  2.49s/it]
#
#
#
#  58%|█████▊    | 73/125 [02:57<02:07,  2.45s/it]
#
#
#
#  59%|█████▉    | 74/125 [02:59<02:05,  2.47s/it]
#
#
#
#  60%|██████    | 75/125 [03:02<02:01,  2.44s/it]
#
#
#
#  61%|██████    | 76/125 [03:04<01:59,  2.44s/it]
#
#
#
#  62%|██████▏   | 77/125 [03:07<01:57,  2.45s/it]
#
#
#
#  62%|██████▏   | 78/125 [03:09<01:55,  2.45s/it]
#
#
#
#  63%|██████▎   | 79/125 [03:12<01:54,  2.49s/it]
#
#
#
#  64%|██████▍   | 80/125 [03:14<01:51,  2.47s/it]
#
#
#
#  65%|██████▍   | 81/125 [03:17<01:48,  2.47s/it]
#
#
#
#  66%|██████▌   | 82/125 [03:19<01:43,  2.42s/it]
#
#
#
#  66%|██████▋   | 83/125 [03:21<01:41,  2.43s/it]
#
#
#
#  67%|██████▋   | 84/125 [03:24<01:39,  2.44s/it]
#
#
#
#  68%|██████▊   | 85/125 [03:26<01:36,  2.42s/it]
#
#
#
#  69%|██████▉   | 86/125 [03:29<01:33,  2.40s/it]
#
#
#
#  70%|██████▉   | 87/125 [03:31<01:31,  2.41s/it]
#
#
#
#  70%|███████   | 88/125 [03:33<01:28,  2.40s/it]
#
#
#
#  71%|███████   | 89/125 [03:36<01:26,  2.40s/it]
#
#
#
#  72%|███████▏  | 90/125 [03:38<01:23,  2.39s/it]
#
#
#
#  73%|███████▎  | 91/125 [03:40<01:20,  2.38s/it]
#
#
#
#  74%|███████▎  | 92/125 [03:43<01:19,  2.41s/it]
#
#
#
#  74%|███████▍  | 93/125 [03:45<01:18,  2.44s/it]
#
#
#
#  75%|███████▌  | 94/125 [03:48<01:15,  2.43s/it]
#
#
#
#  76%|███████▌  | 95/125 [03:50<01:13,  2.45s/it]
#
#
#
#  77%|███████▋  | 96/125 [03:53<01:10,  2.43s/it]
#
#
#
#  78%|███████▊  | 97/125 [03:55<01:07,  2.41s/it]
#
#
#
#  78%|███████▊  | 98/125 [03:58<01:05,  2.44s/it]
#
#
#
#  79%|███████▉  | 99/125 [04:00<01:03,  2.43s/it]
#
#
#
#  80%|████████  | 100/125 [04:03<01:01,  2.45s/it]
#
#
#
#  81%|████████  | 101/125 [04:05<00:58,  2.43s/it]
#
#
#
#  82%|████████▏ | 102/125 [04:07<00:55,  2.43s/it]
#
#
#
#  82%|████████▏ | 103/125 [04:10<00:52,  2.41s/it]
#
#
#
#  83%|████████▎ | 104/125 [04:12<00:50,  2.40s/it]
#
#
#
#  84%|████████▍ | 105/125 [04:14<00:47,  2.40s/it]
#
#
#
#  85%|████████▍ | 106/125 [04:17<00:45,  2.39s/it]
#
#
#
#  86%|████████▌ | 107/125 [04:19<00:43,  2.43s/it]
#
#
#
#  86%|████████▋ | 108/125 [04:22<00:41,  2.47s/it]
#
#
#
#  87%|████████▋ | 109/125 [04:24<00:39,  2.46s/it]
#
#
#
#  88%|████████▊ | 110/125 [04:27<00:36,  2.46s/it]
#
#
#
#  89%|████████▉ | 111/125 [04:29<00:34,  2.44s/it]
#
#
#
#  90%|████████▉ | 112/125 [04:32<00:31,  2.45s/it]
#
#
#
#  90%|█████████ | 113/125 [04:34<00:29,  2.45s/it]
#
#
#
#  91%|█████████ | 114/125 [04:37<00:26,  2.44s/it]
#
#
#
#  92%|█████████▏| 115/125 [04:39<00:24,  2.45s/it]
#
#
#
#  93%|█████████▎| 116/125 [04:42<00:22,  2.46s/it]
#
#
#
#  94%|█████████▎| 117/125 [04:44<00:19,  2.46s/it]
#
#
#
#  94%|█████████▍| 118/125 [04:46<00:17,  2.46s/it]
#
#
#
#  95%|█████████▌| 119/125 [04:49<00:14,  2.46s/it]
#
#
#
#  96%|█████████▌| 120/125 [04:51<00:12,  2.48s/it]
#
#
#
#  97%|█████████▋| 121/125 [04:54<00:09,  2.47s/it]
#
#
#
#  98%|█████████▊| 122/125 [04:56<00:07,  2.46s/it]
#
#
#
#  98%|█████████▊| 123/125 [04:59<00:04,  2.47s/it]
#
#
#
#  99%|█████████▉| 124/125 [05:01<00:02,  2.46s/it]
#
#
#
# 100%|██████████| 125/125 [05:04<00:00,  2.47s/it]
